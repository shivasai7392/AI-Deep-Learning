# %%
import kaggle

# %%
#Upload kaggle.json
#Create a new directory /root/.kaggle
#Move the file kaggle.json to /root/.kaggle

# %%
# !mkdir -p /root/.kaggle
# !mv kaggle.json /root/.kaggle
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory

# %%
import kaggle

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# ...
# sampleSubmission.csv: Skipping, found more recently modified local copy (use --force to force download)
# train.zip: Skipping, found more recently modified local copy (use --force to force download)
# test1.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip -q train.zip
# Out:
# replace train/cat.0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# !ls train
# Out:
# cat.0.jpg      cat.3250.jpg  cat.7751.jpg   dog.12250.jpg  dog.5500.jpg
# cat.10000.jpg  cat.3251.jpg  cat.7752.jpg   dog.12251.jpg  dog.5501.jpg
# cat.10001.jpg  cat.3252.jpg  cat.7753.jpg   dog.12252.jpg  dog.5502.jpg
# cat.10002.jpg  cat.3253.jpg  cat.7754.jpg   dog.12253.jpg  dog.5503.jpg
# cat.10003.jpg  cat.3254.jpg  cat.7755.jpg   dog.12254.jpg  dog.5504.jpg
# cat.10004.jpg  cat.3255.jpg  cat.7756.jpg   dog.12255.jpg  dog.5505.jpg
# cat.10005.jpg  cat.3256.jpg  cat.7757.jpg   dog.12256.jpg  dog.5506.jpg
# cat.10006.jpg  cat.3257.jpg  cat.7758.jpg   dog.12257.jpg  dog.5507.jpg
# cat.10007.jpg  cat.3258.jpg  cat.7759.jpg   dog.12258.jpg  dog.5508.jpg
# cat.10008.jpg  cat.3259.jpg  cat.775.jpg    dog.12259.jpg  dog.5509.jpg
# cat.10009.jpg  cat.325.jpg   cat.7760.jpg   dog.1225.jpg   dog.550.jpg
# cat.1000.jpg   cat.3260.jpg  cat.7761.jpg   dog.12260.jpg  dog.5510.jpg
# cat.10010.jpg  cat.3261.jpg  cat.7762.jpg   dog.12261.jpg  dog.5511.jpg
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow("train/dog.1224.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-1b4c27dea69d> in <module>()
# ----> 1 plt.imshow("train/dog.1224.jpg")
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
import cv2
from PIL import Image

# %%
Image.open("train/dog.1224.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=386x500 at 0x7FA04C1CF128>

# %%
image1 = cv2.imread("train/dog.5492.jpg")

# %%
print(image1)
# Out:
# [[[191 236 240]
#   [166 210 217]
#   [143 184 193]
#   ...
#   [187 216 223]
#   [178 213 223]
#   [182 217 230]]
#
#  [[199 243 250]
#   [165 209 216]
#   [132 172 184]
#   ...
#   [197 226 233]
#   [186 221 231]
#   [185 220 233]]
#
#  [[121 162 171]
#   [153 194 203]
#   [193 231 243]
#   ...
#   [194 223 232]
#   [174 206 217]
#   [162 196 209]]
#
#  ...
#
#  [[103  88  92]
#   [108  93  97]
#   [114  99 103]
#   ...
#   [127 157 186]
#   [146 174 204]
#   [158 186 217]]
#
#  [[113  98 102]
#   [110  95  99]
#   [104  89  93]
#   ...
#   [115 147 176]
#   [146 177 208]
#   [171 202 233]]
#
#  [[117 100 104]
#   [109  92  96]
#   [ 98  81  85]
#   ...
#   [136 172 196]
#   [152 187 213]
#   [171 205 234]]]

# %%
image1.shape
# Out:
# (269, 335, 3)

# %%
plt.imshow(image1)

# %%
image2 = cv2.imread("train/cat.3232.jpg")

# %%
plt.imshow(image2)

# %%
plt.imshow(image2[::0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-ce3cd97a0bb7> in <module>()
# ----> 1 plt.imshow(image2[::0])
#
# ValueError: slice step cannot be zero

# %%
image3  = cv2.imread("train/dog.0.jpg")

# %%
image3.shape
# Out:
# (375, 499, 3)

# %%
plt.imshow(image3)

# %%
#Reading the images
#1. First go to folder "train" and read filename
#2. Second read the image
#3. Resize the image
#4. Check for the image name if cat or dog

# %%
import os
from tqdm.notebook import tqdm

# %%
images = []
labels = []
for filename in tqdm(os.listdir("train")[:1000]):
  image = cv2.imread("train/"+filename)
  image = cv2.resize(image,(200,200))
  images.append(image)
  if(filename.startswith("cat")):
    labels.append(0)
  else:
    labels.append(1)

# %%
images.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-972d9bbd0d84> in <module>()
# ----> 1 images.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
len(image)
# Out:
# 200

# %%
import numpy as np

# %%
images = np.array(images)

# %%
images.shape
# Out:
# (1000, 200, 200, 3)

# %%
labels = np.array(labels)

# %%
labels.shape
# Out:
# (1000,)

# %%
images
# Out:
# array([[[[ 68,  69,  67],
#          [ 68,  69,  67],
#          [ 68,  69,  67],
#          ...,
#          [ 44,  45,  43],
#          [ 40,  38,  37],
#          [ 33,  31,  30]],
#
#         [[ 68,  69,  67],
#          [ 68,  69,  67],
#          [ 68,  69,  67],
#          ...,
#          [ 44,  45,  43],
#          [ 40,  38,  37],
#          [ 33,  31,  30]],
#
#         [[ 68,  69,  67],
#          [ 68,  69,  67],
#          [ 68,  69,  67],
#          ...,
#          [ 44,  45,  43],
#          [ 40,  38,  37],
#          [ 33,  31,  30]],
#
#         ...,
#
#         [[121, 125, 127],
#          [116, 121, 121],
#          [113, 120, 117],
#          ...,
#          [106, 108, 108],
#          [100, 105, 104],
#          [101, 106, 105]],
#
#         [[130, 140, 138],
#          [122, 133, 131],
#          [111, 122, 120],
#          ...,
#          [106, 108, 108],
#          [102, 107, 106],
#          [102, 107, 106]],
#
#         [[126, 137, 135],
# ...

# %%
images.shape
# Out:
# (1000, 200, 200, 3)

# %%
labels.shape
# Out:
# (1000,)

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.activations import relu,softmax
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import SGD

# %%
model = Sequential()
model.add(Flatten(input_shape = (200,200,3)))
model.add(Dense(1024,activation=relu))
model.add(Dense(512,activation=relu))
model.add(Dense(2,activation=softmax))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 120000)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              122881024
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# ...
# Total params: 123,406,850
# Trainable params: 123,406,850
# Non-trainable params: 0
# _________________________________________________________________

# %%
1024*200*200*3 + 1024
# Out:
# 122881024

# %%
512*200*200*3 + 512
# Out:
# 61440512

# %%
512*2 + 2
# Out:
# 1026

# %%
labels = tf.keras.utils.to_categorical(labels)

# %%
model.compile(optimizer=SGD(),loss=categorical_crossentropy,metrics = ["acc"])

# %%
model.fit(images,labels,epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 2/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 3/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 4/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 5/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 6/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 7/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 8/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 9/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 10/100
# 32/32 [==============================] - 0s 11ms/step - loss: nan - acc: 0.4790
# Epoch 11/100
# ...
